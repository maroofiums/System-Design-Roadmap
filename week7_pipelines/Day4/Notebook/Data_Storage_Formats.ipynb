# %%
import pandas as pd
import seaborn as sns
import os
import time

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.to_csv("/content/titanic_data.csv")

# %%
df.to_json("/content/titanic_data.json")

# %%
df.to_parquet("/content/titanic_data.parquet")

# %%
csv_size = os.path.getsize("/content/titanic_data.csv")
json_size = os.path.getsize("/content/titanic_data.json")
parquet_size = os.path.getsize("/content/titanic_data.parquet")

# %%
print("\nFile Size Comparison (in bytes)")
print(f"CSV Size: {csv_size}")
print(f"JSON Size: {json_size}")
print(f"Parquet Size: {parquet_size}")
# Out:
# File Size Comparison (in bytes)
# CSV Size: 60473
# JSON Size: 150185
# Parquet Size: 14954

# %%
print("\nFile Size Comparison (in KB)")
print(f"CSV Size: {csv_size/1024:.2f} KB")
print(f"JSON Size: {json_size/1024:.2f} KB")
print(f"Parquet Size: {parquet_size/1024:.2f} KB")
# Out:
# File Size Comparison (in KB)
# CSV Size: 59.06 KB
# JSON Size: 146.67 KB
# Parquet Size: 14.60 KB

# %%
start = time.time()
csv_df = pd.read_csv("titanic_data.csv")
csv_time = time.time() - start

print(f"CSV Load Time: {csv_time:.6f} seconds")
# Out:
# CSV Load Time: 0.005427 seconds

# %%
start = time.time()
json_df = pd.read_json("titanic_data.json")
json_time = time.time() - start

print(f"JSON Load Time: {json_time:.6f} seconds")
# Out:
# JSON Load Time: 0.015680 seconds

# %%
start = time.time()
parquet_df = pd.read_parquet("titanic_data.parquet")
parquet_time = time.time() - start

print(f"Parquet Load Time: {parquet_time:.6f} seconds")
# Out:
# Parquet Load Time: 0.007763 seconds

# %%
print("Final Analysis")

sizes = {
    "CSV": csv_size,
    "JSON": json_size,
    "Parquet": parquet_size
}

times = {
    "CSV": csv_time,
    "JSON": json_time,
    "Parquet": parquet_time
}

smallest_file = min(sizes, key=sizes.get)
fastest_load = min(times, key=times.get)

print(f"Smallest File Format: {smallest_file}")
print(f"Fastest Loading Format: {fastest_load}")
# Out:
# Final Analysis
# Smallest File Format: Parquet
# Fastest Loading Format: CSV
